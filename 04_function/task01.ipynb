# %%
def validate_username(username):
    """
    ユーザー名のバリデーションを行う関数
    """
    # 1. 文字数のチェック（5文字以上15文字以内）
    if not (5 <= len(username) <= 15):
        print("エラー: ユーザー名は5文字以上15文字以内で入力してください")
        return False
    
    # 2. 空白のチェック
    if " " in username:
        print("エラー: ユーザー名に空白を含めることはできません")
        return False
    
    # 3. 英数字のみかチェック
    # isalnum()は英数字のみの場合にTrueを返すメソッド
    if not username.isalnum():
        print("エラー: ユーザー名は英数字のみ使用できます")
        return False
    
    # すべての条件をクリアした場合
    return True

# --- 呼び出し側の処理 ---
input_name = input("ユーザー名を入力してください: ")

if validate_username(input_name):
    print("ユーザー名は有効です")
else:
    print("不正なユーザー名です")
